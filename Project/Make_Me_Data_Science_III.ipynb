# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC5502/blob/main/Project/Make_Me_Data_Science_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Make Me Data Science III Complete
#
# Name

# %% [markdown]
# ## Getting Started
#
# * Colab - get notebook from gitmystuff DTSC5502 repository
# * Save a Copy in Drive
# * Remove Copy of
# * Edit your name
# * Clean up Colab Notebooks folder
# * Submit shared link

# %% [markdown]
# ## Objectives
#
# See Table of Contents
#
# A Data Scientist’s roles and responsibilities include extracting data from multiple sources, using machine learning tools to organize data, process, clean, and validate the data, analyze the data for information and patterns, develop prediction systems, present the data in a clear manner, and propose solutions and strategies.
#
# https://www.simplilearn.com/data-scientist-job-description-article#:~:text=A%20Data%20Scientist's%20roles%20and,manner%2C%20and%20propose%20solutions%20and
#
# Data cleaning is essential in preparing data for analysis, and it is important to handle potential data errors before presenting results. Comparing model results with and without the data errors allows presentation of graphical evidence to show that data cleaning is worth the time spent.
#
# https://chance.amstat.org/2020/02/data-cleaning/#:~:text=Data%20cleaning%20is%20essential%20in,is%20worth%20the%20time%20spent.

# %%
# ! git clone https://github.com/gitmystuff/preppy.git

# %%
# import shutil

# # Source file path (within your Drive)
# source_file = '/content/drive/MyDrive/Colab Notebooks/preppy report.py'

# # Destination path (root of your Drive)
# destination_path = '/content/preppy/utils/report.py'

# # Copy the file
# shutil.copy(source_file, destination_path)

# %% [markdown]
# ## Outline
#
# * Set the Stage
# * Create the Data
# * Data Prep
# * Exploratory Data Analysis
# * Feature Engineering
# * Feature Selection
# * Data Modeling
# * Model Evaluation
# * Model Fine-Tuning
# * Model Deployment

# %% [markdown]
# ## Create the Data

# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-30.3.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from Faker) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Downloading Faker-30.3.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-30.3.0

# %%
state_names=["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]

# %%
# create demographic data
import numpy as np
import pandas as pd
from faker import Faker
fake = Faker()

output = []
for x in range(1000):
  binary = np.random.choice(['binary_1', 'binary_2'], p=[0.5, 0.5])
  output.append({
        'binary': binary, # sex assigned at birth
        'given_name': fake.first_name_female() if binary=='binary_1' else fake.first_name_male(),
        'surname': fake.last_name(),
        'date_of_birth': fake.date_of_birth(),
        'phone_number': fake.phone_number(),
        'email': fake.email(),
        'address': fake.address(),
        'city': fake.city(),
        'state': np.random.choice(state_names),
        'zipcode': fake.zipcode(),
        })

demographics = pd.DataFrame(output)
demographics.head()
# Out:
#      binary given_name surname date_of_birth          phone_number  \
# 0  binary_1    Jessica  Walker    2021-02-13      894.605.6413x668
# 1  binary_2      Terry    Rose    1960-07-06            2933027807
# 2  binary_1      April  Hunter    1935-05-03  +1-968-801-0294x1103
# 3  binary_1    Madison  Moreno    1935-03-16     (692)760-8739x009
# 4  binary_2     Norman   Jones    1919-07-09         (932)644-4521
#
#                       email  \
# 0    jennifer27@example.com
# 1     charles09@example.net
# 2  russelltracy@example.net
# 3        llewis@example.org
# 4    lauraallen@example.org
#
#                                              address                city  \
# 0  1215 Dominguez Shore Apt. 902\nPort Jesse, NV ...  West Michelleville
# 1         411 Lewis Rue\nEast Williammouth, SC 67052       South Chelsea
# 2           301 Wiggins Keys\nEast Jessica, RI 33180          Lynchmouth
# 3       54341 Gaines Common\nLake Margaret, VI 98618          New Adrian
# 4   783 Carl Row Suite 301\nEast Alexandra, NE 14114            Coleberg
#
#         state zipcode
# 0        Ohio   03099
# 1  New Jersey   81454
# 2      Alaska   27852
# 3      Hawaii   18060
# 4     Indiana   29923

# %%
# create a base dataframe with 1 dependent variable and 2 features, both informative
from sklearn.datasets import make_regression, make_classification

X, y = make_regression(n_samples=1000, n_features=2, n_informative=2, noise=0.1, random_state=42)
df = pd.DataFrame(X, columns=['informative_1', 'informative_2'])
df = pd.concat([demographics, df], axis=1).reset_index(drop=True)
df['target'] = y
df.head()
# Out:
#      binary   given_name  surname date_of_birth            phone_number  \
# 0  binary_1      Chelsea  Summers    1999-08-04           (472)296-1695
# 1  binary_2       Andrew    Lewis    1930-06-15  001-933-541-5143x79469
# 2  binary_2  Christopher    Davis    1945-06-24            918-562-6968
# 3  binary_2       Albert   Rivera    1993-03-23     +1-492-771-9503x186
# 4  binary_2        David     Webb    2024-08-01   +1-348-353-0553x91179
#
#                        email  \
# 0          wkerr@example.com
# 1  leblancteresa@example.com
# 2    pateledward@example.org
# 3        jacob44@example.com
# 4  rebeccabarnes@example.com
#
#                                              address              city  \
# 0   80974 Jeffrey Mountains\nWest Benjamin, IL 82801      Richardburgh
# 1          4935 Michelle Tunnel\nSherryton, NJ 80330  East Crystalfurt
# 2      370 Christopher Turnpike\nNew Julie, TN 30505      Wendyborough
# 3  690 Thomas Brook Suite 796\nWest Kristafort, A...         Lopezside
# 4  471 Jones Way Apt. 776\nNew Nicholasborough, S...      Hollyborough
#
#          state zipcode  informative_1  informative_2     target
# 0  Mississippi   78402      -0.167118       0.146714  -5.926650
# 1      Florida   29074      -0.020902       0.117327  -0.202458
# 2  Mississippi   58755       0.150419       0.364961   8.625180
# 3        Idaho   74657       0.555604       0.089581  23.044850
# 4     Arkansas   84791       0.058209      -1.142970  -5.265220

# %% [markdown]
# ## Automation Functions
#
# 1. gen_null(series, perc)
# 2. gen_quasi_constants(primary_label, variation_percentage=.2, replace=False)
# 3. gen_normal_data(mu=0, std=1, size=len(df))
# 4. gen_uniform_data(size=len(df))
# 5. gen_multivariate_normal_data(mean=[0, 0], cov=[[1, 0], [0, 1]], size=len(df))
# 6. gen_correlated_normal_series(original_series, target_correlation, size=len(df))
# 7. gen_correlated_uniform_series(original_series, correlation_coefficient=0, size=len(df))
# 8. gen_outliers(mean=0, std_dev=1, size=len(df), outlier_percentage=0.1, outlier_magnitude=3)
# 9. gen_standard_scaling(mean=50, std_dev=10, size=len(df), scale_factor=1000)
# 10. gen_minmax_scaling(mean=50, std_dev=10, size=len(df), range_factor=10)
# 11. random_choice_data(choices, size)

# %%
# functions
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy.optimize import minimize


def gen_null(series, perc):
  """
  Introduces null values (np.nan) into a list based on a specified percentage.

  Args:
      var: The variable to modify.
      perc: The percentage of values to replace with nulls (0-100).

  Returns:
      The modified variable with null.
  """
  var = series.copy()
  num_nulls = int(len(var) * (perc / 100))
  indices_to_replace = np.random.choice(len(var), num_nulls, replace=False)

  for idx in indices_to_replace:
      var[idx] = np.nan

  return var

def gen_quasi_constants(primary_label, variation_percentage=.2, size=len(df)):
  """
  Generates quasi-constant labels for a Series, with a small percentage of variation.

  Args:
      primary_label: The main label to use for most values.
      variation_percentage: The percentage of labels to vary (0-100).

  Returns:
      A new Series containing the quasi-constant labels.
  """

  series = pd.Series(np.full(size, primary_label))
  num_variations = int(size * (variation_percentage / 100))
  variation_indices = np.random.choice(series.index, num_variations, replace=False)
  primary_label = primary_label + '_0'
  variation1 = primary_label + '_1'
  variation2 = primary_label + '_2'

  labels = pd.Series([primary_label] * len(series), index=series.index)
  labels.loc[variation_indices] = np.random.choice([variation1, variation2], size=num_variations)  # Adjust variations as needed

  return labels

def gen_normal_data(mu=0, std=1, size=len(df)):
  """
  Generates a normal dataset given the mean and standard deviation

  Args:
        mu: The mean of the normal distribution.
        std: The standard deviation of the normal distribution.
        size: The number of data points to generate.

  Returns:
        A normally distributed series.
  """
  return np.random.normal(mu, std, size)

def gen_uniform_data(size=len(df)):
  """
  Generates a uniform dataset

  Args:
        size: The number of data points to generate.

  Returns:
        A uniform distributed series.
  """
  return np.random.uniform(size=size)

def gen_multivariate_normal_data(mean=[0, 0], cov=[[1, 0], [0, 1]], size=len(df)):
  """
  Generates two datasets with a multivariate normal distribution given the mean and covariance matrix

  Args:
        mean: The mean of each of the datasets.
        cov: The covariance matrix of the datasets.
        size: The number of data points to generate.

  Returns:
        Two correlated series.
  """
  ds1, ds2 = np.random.multivariate_normal(mean, cov, size, tol=1e-6).T # ds = dataset
  return ds1, ds2

def gen_correlated_normal_series(original_series, target_correlation, size=len(df)):
  """
  Generates a correlated series based on a given series.

  This function takes an original series as input and generates a new series
  that is correlated with the original series. The correlation between the
  original and generated series is approximately equal to the specified
  target correlation.

  The generated series is created by linearly transforming the original series
  and adding Gaussian noise with an adjusted standard deviation to achieve the
  desired correlation.

  Args:
      original_series (numpy.ndarray): The original series.
      target_correlation (float): The desired Pearson correlation coefficient
          between the original and generated series.

  Returns:
      numpy.ndarray: The generated correlated series.
  """
  return np.mean(original_series) + target_correlation * (original_series - np.mean(original_series)) \
  +  np.random.normal(0, np.sqrt(1 - target_correlation**2) * np.std(original_series), len(original_series))
  """
  Explanation

  This one-liner leverages the properties of linear transformations and normal distributions to generate a correlated series.

  It first centers the original_series by subtracting its mean.
  It then scales this centered series by the target_correlation.
  Finally, it adds Gaussian noise with a standard deviation adjusted to ensure the overall correlation matches the target_correlation.
  """

def gen_correlated_uniform_series(original_series, correlation_coefficient=0, size=len(df)):
  """
  Work in progress

  Generates a new series correlated with the given series based on the specified correlation coefficient,
  using rank correlation to ensure the generated series follows a uniform distribution.

  Args:
      original_series (numpy.ndarray or list): The original series.
      correlation_coefficient (float): The desired correlation coefficient between the original and generated series.
      size: The number of data points to generate.

  Returns:
      The generated correlated series with a uniform distribution.
  """
  z_scores = (original_series - np.mean(original_series)) / np.std(original_series)
  correlation_coefficient=.7
  return norm.cdf(correlation_coefficient * norm.ppf(np.random.uniform(size=size)) + np.sqrt(1 - correlation_coefficient**2) * z_scores)

def pearson_r_func(x, y, y_mean, y_std, desired_r):
    x_mean = np.mean(x)
    x_std = np.std(x)
    numerator = np.sum((x - x_mean) * (y - y_mean))
    denominator = x_std * y_std * len(x)
    calculated_r = numerator / denominator
    return (calculated_r - desired_r)**2  # Minimize the squared difference

def minimize_r(original_series, target_correlation, size=len(df)):
    y = original_series
    y_mean = np.mean(y)
    y_std = np.std(y)
    desired_r = target_correlation

    # Initial guess for x values
    x0 = np.random.uniform(size=len(original_series))

    # Solve for x
    result = minimize(pearson_r_func, x0, args=(y, y_mean, y_std, desired_r))

    if result.success:
        x_solution = result.x
        # print("Solution for x:", x_solution)
        return x_solution
    else:
        print("Optimization failed.")

def gen_outliers(mean=0, std_dev=1, size=len(df), outlier_percentage=0.1, outlier_magnitude=3):
    """
    Generates a normal distribution with outliers.

    Args:
        mean (float): The mean of the normal distribution.
        std_dev (float): The standard deviation of the normal distribution.
        size (int): The number of samples to generate.
        outlier_percentage (float): The percentage of outliers to introduce (between 0 and 1).
        outlier_magnitude (float): The magnitude by which outliers deviate from the mean.

    Returns:
        numpy.ndarray: The generated data with outliers.
    """
    data = np.random.normal(mean, std_dev, size)
    num_outliers = int(size * outlier_percentage)
    outlier_indices = np.random.choice(size, num_outliers, replace=False)
    for index in outlier_indices:
        if np.random.rand() < 0.5:
            data[index] += outlier_magnitude
        else:
            data[index] -= outlier_magnitude

    return data

def gen_standard_scaling(mean=50, std_dev=10, size=len(df), scale_factor=1000):
  """
  Generates data with a specified mean and standard deviation, then scales it by a factor to create a distribution needing scaling.

  Args:
      mean (float): The mean of the original distribution.
      std_dev (float): The standard deviation of the original distribution.
      size (int): The number of samples to generate.
      scale_factor (float): The factor by which to scale the original distribution.

  Returns:
      numpy.ndarray: The generated data needing scaling.
  """
  original_data = np.random.normal(mean, std_dev, size)
  return original_data * scale_factor

def gen_minmax_scaling(mean=50, std_dev=10, size=len(df), range_factor=10):
  """
  Generates data with a specified mean and standard deviation, then scales and shifts it to create a distribution needing MinMax scaling.

  Args:
      mean (float): The mean of the original distribution.
      std_dev (float): The standard deviation of the original distribution.
      size (int): The number of samples to generate.
      range_factor (float): The factor to expand the range of the original distribution.

  Returns:
      numpy.ndarray: The generated data needing scaling.
  """

  # Generate the original data
  original_data = np.random.normal(mean, std_dev, size)

  # Expand the range of the data
  min_val = np.min(original_data)
  max_val = np.max(original_data)
  return (original_data - min_val) * range_factor + min_val

def random_choice_data(choices, size):
  """
  Generates a new series correlated with the given series based on the specified correlation coefficient,
  using rank correlation to ensure the generated series follows a uniform distribution.

  Args:
      original_series (numpy.ndarray or list): The original series.
      correlation_coefficient (float): The desired correlation coefficient between the original and generated series.

  Returns:
      numpy.ndarray: The generated correlated series with a uniform distribution.
  """
  return np.random.choice(choices, size=size)

# %%
# categorical variables with little correlation to sales
df['random choice 2'] = random_choice_data(['Rand Choice 1', 'Rand Choice 2'], size=len(df))
df['random choice 4'] = random_choice_data(['North', 'South', 'East', 'West'], size=len(df))
df['random choice 7'] = random_choice_data(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], size=len(df))

# categorical random choices with random # of labels
num_labels = np.random.randint(3, 5)
df[f'random label num {num_labels}'] = random_choice_data([f'label num lo {i}' for i in range(1, num_labels + 1)], size=len(df))

num_labels = np.random.randint(10, 15)
df[f'random label num {num_labels}'] = random_choice_data([f'label num hi {i}' for i in range(1, num_labels + 1)], size=len(df))

# %%
# categorical variables correlated with target
df['pd qcut1'] = pd.qcut(df['target'], 2, labels=['Low', 'High']) # bi label
df['pd qcut2'] = pd.qcut(df['target'], 4, labels=['Q1', 'Q2', 'Q3', 'Q4']) # 4 labels

quantiles = [0, 0.1, 0.2, 0.4, 0.6, 0.8, 1]
df['pd qcut3'] = pd.qcut(df['target'], quantiles, labels=['G1', 'G2', 'G3', 'G4', 'G5', 'G6']) # 6 labels

# %%
# generate four numerical normally distributed continuous features that have a correlation greater than absolute value of .5 with each other
# gen_multivariate_normal_data(mean=[0, 0], cov=[[1, 0], [0, 1]], size=len(df))
df['multicollinearity 1'], df['multicollinearity 2'] = gen_multivariate_normal_data(mean=[0, 0], cov=[[1, .7], [.7, 1]], size=len(df))
df['multicollinearity 3'], df['multicollinearity 4'] = gen_multivariate_normal_data(mean=[0, 0], cov=[[1, .9], [.9, 1]], size=len(df))

# %%
# generate two normally distributed features that are correlated with the target
# gen_correlated_normal_series(original_series, target_correlation, size=len(df))
df['correlated w target 1'] = gen_correlated_normal_series(df['target'], target_correlation=.5)
df['correlated w target 2'] = gen_correlated_normal_series(df['target'], target_correlation=.7)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   binary                 1000 non-null   object
#  1   given_name             1000 non-null   object
#  2   surname                1000 non-null   object
#  3   date_of_birth          1000 non-null   object
#  4   phone_number           1000 non-null   object
#  5   email                  1000 non-null   object
#  6   address                1000 non-null   object
#  7   city                   1000 non-null   object
#  8   state                  1000 non-null   object
#  9   zipcode                1000 non-null   object
#  10  informative_1          1000 non-null   float64
#  11  informative_2          1000 non-null   float64
#  12  target                 1000 non-null   float64
#  13  random choice 2        1000 non-null   object
#  14  random choice 4        1000 non-null   object
#  15  random choice 7        1000 non-null   object
#  16  random label num 3     1000 non-null   object
#  17  random label num 12    1000 non-null   object
#  18  pd qcut1               1000 non-null   category
#  19  pd qcut2               1000 non-null   category
#  20  pd qcut3               1000 non-null   category
#  21  multicollinearity 1    1000 non-null   float64
#  22  multicollinearity 2    1000 non-null   float64
#  23  multicollinearity 3    1000 non-null   float64
#  24  multicollinearity 4    1000 non-null   float64
#  25  correlated w target 1  1000 non-null   float64
#  26  correlated w target 2  1000 non-null   float64
# dtypes: category(3), float64(9), object(15)
# memory usage: 191.1+ KB

# %%
# generate two uniformly distributed features that are correlated with the target
# gen_correlated_uniform_series(original_series, correlation_coefficient=0, size=len(df))
df['uniform corr 1'] = gen_correlated_uniform_series(df['target'])
df['uniform corr 2'] = gen_correlated_uniform_series(df['target'])

print(df[['uniform corr 1', 'uniform corr 2', 'target']].corr())
df[['uniform corr 1', 'uniform corr 2']].hist();
# Out:
#                 uniform corr 1  uniform corr 2    target
# uniform corr 1        1.000000        0.498039  0.715810
# uniform corr 2        0.498039        1.000000  0.709056
# target                0.715810        0.709056  1.000000

# %%
# create two features that are duplicates of other features
df['duplicate_1'] = df['informative_1']
df['duplicate_2'] = df['informative_2']

# %%
# create two numerical features with outliers
df['outliers 1'] = gen_outliers(mean=0, std_dev=1, size=len(df), outlier_percentage=0.1, outlier_magnitude=3)
df['outliers 2'] = gen_outliers(mean=3, std_dev=2, size=len(df), outlier_percentage=0.2, outlier_magnitude=2)

# %%
# create a numerical feature that needs standard scaling
df['standard scaling'] = gen_standard_scaling()

# %%
# create a numerical feature that needs min max scaling
df['min max scaling'] = gen_minmax_scaling()

# %%
# generate null values
for col in df.drop(['informative_1', 'informative_2', 'target'], axis=1).columns:
    df[col] = gen_null(df[col], np.random.choice([0, 5, 10, 20, 30, 50], size=1).item())

# %%
# create two features that have constant values
df['constant_1'] = 'constant_value'
df['constant_2'] = 'constant_value'

# %%
# create two features with semi constant values
df['semi_constant_1'] = gen_quasi_constants('q_const', variation_percentage = 1)
df['semi_constant_2'] = gen_quasi_constants('q_const', variation_percentage = 1)

# %%
print(df.info())  # check your work
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   binary                 500 non-null    object
#  1   given_name             900 non-null    object
#  2   surname                700 non-null    object
#  3   date_of_birth          700 non-null    object
#  4   phone_number           950 non-null    object
#  5   email                  1000 non-null   object
#  6   address                900 non-null    object
#  7   city                   500 non-null    object
#  8   state                  700 non-null    object
#  9   zipcode                700 non-null    object
#  10  informative_1          1000 non-null   float64
#  11  informative_2          1000 non-null   float64
#  12  target                 1000 non-null   float64
#  13  random choice 2        950 non-null    object
#  14  random choice 4        900 non-null    object
#  15  random choice 7        800 non-null    object
#  16  random label num 3     500 non-null    object
#  17  random label num 12    1000 non-null   object
#  18  pd qcut1               1000 non-null   category
#  19  pd qcut2               500 non-null    category
#  20  pd qcut3               900 non-null    category
#  21  multicollinearity 1    950 non-null    float64
#  22  multicollinearity 2    1000 non-null   float64
#  23  multicollinearity 3    800 non-null    float64
#  24  multicollinearity 4    950 non-null    float64
#  25  correlated w target 1  950 non-null    float64
#  26  correlated w target 2  1000 non-null   float64
#  27  uniform corr 1         950 non-null    float64
#  28  uniform corr 2         800 non-null    float64
#  29  duplicate_1            500 non-null    float64
#  30  duplicate_2            500 non-null    float64
#  31  outliers 1             700 non-null    float64
#  32  outliers 2             800 non-null    float64
#  33  standard scaling       1000 non-null   float64
#  34  min max scaling        800 non-null    float64
#  35  constant_1             1000 non-null   object
#  36  constant_2             1000 non-null   object
#  37  semi_constant_1        1000 non-null   object
#  38  semi_constant_2        1000 non-null   object
# dtypes: category(3), float64(17), object(19)
# memory usage: 284.8+ KB
# None

# %%
# add duplicates
dupes = df.loc[0:9]
df = pd.concat([df, dupes], axis=0)

# shuffle all columns
# df = df.sample(frac=1).reset_index(drop=True)
# df = df.sample(frac=1, axis=1)

# shuffle selected columns
demographic_columns = demographics.columns
remaining_columns = [col for col in df.columns if col not in demographic_columns]
# print(remaining_columns)
np.random.shuffle(remaining_columns)

# Reassemble the DataFrame with the shuffled columns
df = df[list(demographic_columns) + list(remaining_columns)]

# move target to the end of the list
target = 'target'
df = df[df.drop('target', axis=1).columns.tolist() + [target]]

print(df.shape)
print(df.info())
df.head()
# Out:
# (1010, 39)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1010 entries, 0 to 9
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   binary                 505 non-null    object
#  1   given_name             909 non-null    object
#  2   surname                710 non-null    object
#  3   date_of_birth          705 non-null    object
#  4   phone_number           958 non-null    object
#  5   email                  1010 non-null   object
#  6   address                909 non-null    object
#  7   city                   502 non-null    object
#  8   state                  707 non-null    object
#  9   zipcode                705 non-null    object
#  10  multicollinearity 1    960 non-null    float64
#  11  random label num 3     505 non-null    object
#  12  informative_2          1010 non-null   float64
#  13  random label num 12    1010 non-null   object
#  14  uniform corr 1         960 non-null    float64
#  15  informative_1          1010 non-null   float64
#  16  correlated w target 2  1010 non-null   float64
#  17  uniform corr 2         809 non-null    float64
#  18  multicollinearity 3    809 non-null    float64
#  19  constant_2             1010 non-null   object
#  20  random choice 7        807 non-null    object
#  21  correlated w target 1  958 non-null    float64
#  22  min max scaling        808 non-null    float64
#  23  multicollinearity 2    1010 non-null   float64
#  24  pd qcut2               504 non-null    category
#  25  multicollinearity 4    960 non-null    float64
#  26  duplicate_2            504 non-null    float64
#  27  pd qcut3               910 non-null    category
#  28  duplicate_1            503 non-null    float64
#  29  outliers 1             705 non-null    float64
#  30  standard scaling       1010 non-null   float64
#  31  pd qcut1               1010 non-null   category
#  32  semi_constant_2        1010 non-null   object
#  33  semi_constant_1        1010 non-null   object
#  34  random choice 4        909 non-null    object
#  35  random choice 2        960 non-null    object
#  36  outliers 2             809 non-null    float64
#  37  constant_1             1010 non-null   object
#  38  target                 1010 non-null   float64
# dtypes: category(3), float64(17), object(19)
# memory usage: 295.4+ KB
# None
#      binary   given_name  surname date_of_birth            phone_number  \
# 0  binary_1      Chelsea  Summers           NaN           (472)296-1695
# 1       NaN       Andrew    Lewis    1930-06-15  001-933-541-5143x79469
# 2  binary_2  Christopher    Davis    1945-06-24                     NaN
# 3  binary_2       Albert   Rivera           NaN     +1-492-771-9503x186
# 4  binary_2        David     Webb           NaN   +1-348-353-0553x91179
#
#                        email  \
# 0          wkerr@example.com
# 1  leblancteresa@example.com
# 2    pateledward@example.org
# 3        jacob44@example.com
# 4  rebeccabarnes@example.com
#
#                                              address          city  \
# 0   80974 Jeffrey Mountains\nWest Benjamin, IL 82801           NaN
# 1          4935 Michelle Tunnel\nSherryton, NJ 80330           NaN
# 2      370 Christopher Turnpike\nNew Julie, TN 30505  Wendyborough
# 3  690 Thomas Brook Suite 796\nWest Kristafort, A...           NaN
# 4  471 Jones Way Apt. 776\nNew Nicholasborough, S...           NaN
#
#          state zipcode  ...  outliers 1 standard scaling  pd qcut1  \
# 0          NaN     NaN  ...   -0.917084     36236.363279       Low
# 1      Florida   29074  ...    0.144835     49006.807773       Low
# 2  Mississippi     NaN  ...   -0.226238     43497.263940      High
# 3        Idaho   74657  ...         NaN     56782.967290      High
# 4     Arkansas     NaN  ...         NaN     53848.429681       Low
#
#   semi_constant_2  semi_constant_1  random choice 4  random choice 2  \
# 0       q_const_0        q_const_0            North    Rand Choice 2
# 1       q_const_0        q_const_0            North    Rand Choice 1
# 2       q_const_0        q_const_0             West    Rand Choice 2
# 3       q_const_0        q_const_0            North    Rand Choice 2
# 4       q_const_0        q_const_0             East    Rand Choice 1
#
#    outliers 2      constant_1     target
# 0    5.515177  constant_value  -5.926650
# 1    4.783148  constant_value  -0.202458
# 2    1.715744  constant_value   8.625180
# 3    6.437325  constant_value  23.044850
# 4    3.929120  constant_value  -5.265220
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Exploratory Data Analysis
#
# Exploratory data analysis (EDA) is a data analysis method that helps data scientists understand their data and identify patterns. It's often used as the first step in data analysis.

# %% [markdown]
# ## Correlation

# %%
# code along
df._get_numeric_data().corr().round(2)
# Out:
#                        multicollinearity 1  informative_2  uniform corr 1  \
# multicollinearity 1                   1.00          -0.03            0.06
# informative_2                        -0.03           1.00            0.12
# uniform corr 1                        0.06           0.12            1.00
# informative_1                         0.06           0.00            0.70
# correlated w target 2                 0.06           0.15            0.51
# uniform corr 2                        0.04           0.12            0.50
# multicollinearity 3                  -0.09          -0.03            0.01
# correlated w target 1                 0.04           0.12            0.33
# min max scaling                       0.02          -0.05           -0.04
# multicollinearity 2                   0.72          -0.02            0.02
# multicollinearity 4                  -0.04          -0.05            0.01
# duplicate_2                          -0.01           1.00            0.03
# duplicate_1                           0.04           0.04            0.72
# outliers 1                            0.04           0.05           -0.01
# standard scaling                      0.04           0.05            0.04
# outliers 2                           -0.01          -0.01            0.05
# target                                0.05           0.17            0.71
#
#                        informative_1  correlated w target 2  uniform corr 2  \
# multicollinearity 1             0.06                   0.06            0.04
# informative_2                   0.00                   0.15            0.12
# uniform corr 1                  0.70                   0.51            0.50
# informative_1                   1.00                   0.69            0.70
# correlated w target 2           0.69                   1.00            0.49
# uniform corr 2                  0.70                   0.49            1.00
# multicollinearity 3             0.01                  -0.01            0.04
# correlated w target 1           0.48                   0.32            0.36
# min max scaling                -0.01                  -0.02           -0.01
# multicollinearity 2             0.02                   0.02           -0.03
# multicollinearity 4             0.01                  -0.02            0.03
# duplicate_2                    -0.10                   0.05            0.04
# duplicate_1                     1.00                   0.70            0.71
# outliers 1                     -0.03                  -0.02           -0.03
# standard scaling                0.02                   0.02            0.06
# outliers 2                      0.05                  -0.00            0.05
# target                          0.99                   0.70            0.71
#
#                        multicollinearity 3  correlated w target 1  \
# multicollinearity 1                  -0.09                   0.04
# informative_2                        -0.03                   0.12
# uniform corr 1                        0.01                   0.33
# informative_1                         0.01                   0.48
# correlated w target 2                -0.01                   0.32
# uniform corr 2                        0.04                   0.36
# multicollinearity 3                   1.00                  -0.01
# correlated w target 1                -0.01                   1.00
# min max scaling                      -0.06                   0.01
# multicollinearity 2                  -0.05                   0.02
# multicollinearity 4                   0.90                  -0.04
# duplicate_2                          -0.05                   0.04
# duplicate_1                          -0.01                   0.49
# outliers 1                           -0.04                  -0.02
# standard scaling                     -0.02                   0.03
# outliers 2                            0.00                  -0.02
# target                                0.01                   0.49
#
#                        min max scaling  multicollinearity 2  \
# multicollinearity 1               0.02                 0.72
# informative_2                    -0.05                -0.02
# uniform corr 1                   -0.04                 0.02
# informative_1                    -0.01                 0.02
# correlated w target 2            -0.02                 0.02
# uniform corr 2                   -0.01                -0.03
# multicollinearity 3              -0.06                -0.05
# correlated w target 1             0.01                 0.02
# min max scaling                   1.00                -0.03
# multicollinearity 2              -0.03                 1.00
# multicollinearity 4              -0.02                -0.02
# duplicate_2                      -0.06                 0.03
# duplicate_1                      -0.06                -0.02
# outliers 1                        0.01                 0.01
# standard scaling                  0.05                 0.02
# outliers 2                        0.01                -0.01
# target                           -0.01                 0.01
#
#                        multicollinearity 4  duplicate_2  duplicate_1  \
# multicollinearity 1                  -0.04        -0.01         0.04
# informative_2                        -0.05         1.00         0.04
# uniform corr 1                        0.01         0.03         0.72
# informative_1                         0.01        -0.10         1.00
# correlated w target 2                -0.02         0.05         0.70
# uniform corr 2                        0.03         0.04         0.71
# multicollinearity 3                   0.90        -0.05        -0.01
# correlated w target 1                -0.04         0.04         0.49
# min max scaling                      -0.02        -0.06        -0.06
# multicollinearity 2                  -0.02         0.03        -0.02
# multicollinearity 4                   1.00        -0.06         0.00
# duplicate_2                          -0.06         1.00        -0.10
# duplicate_1                           0.00        -0.10         1.00
# outliers 1                           -0.01         0.04        -0.05
# standard scaling                     -0.03         0.00         0.01
# outliers 2                            0.01         0.06         0.03
# target                                0.00         0.07         0.99
#
#                        outliers 1  standard scaling  outliers 2  target
# multicollinearity 1          0.04              0.04       -0.01    0.05
# informative_2                0.05              0.05       -0.01    0.17
# uniform corr 1              -0.01              0.04        0.05    0.71
# informative_1               -0.03              0.02        0.05    0.99
# correlated w target 2       -0.02              0.02       -0.00    0.70
# uniform corr 2              -0.03              0.06        0.05    0.71
# multicollinearity 3         -0.04             -0.02        0.00    0.01
# correlated w target 1       -0.02              0.03       -0.02    0.49
# min max scaling              0.01              0.05        0.01   -0.01
# multicollinearity 2          0.01              0.02       -0.01    0.01
# multicollinearity 4         -0.01             -0.03        0.01    0.00
# duplicate_2                  0.04              0.00        0.06    0.07
# duplicate_1                 -0.05              0.01        0.03    0.99
# outliers 1                   1.00              0.00       -0.01   -0.03
# standard scaling             0.00              1.00       -0.04    0.03
# outliers 2                  -0.01             -0.04        1.00    0.05
# target                      -0.03              0.03        0.05    1.00

# %%
# show correlation between the features
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# correlation matrix
sns.set(style="white")

# compute the correlation matrix
corr = df._get_numeric_data().corr().round(2)

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
# f, ax = plt.subplots()
f = plt.figure(figsize=(12, 12))

# generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

plt.tight_layout()

# %%
# calculate the correlation matrix
corr_matrix = df._get_numeric_data().corr()

# Create a mask for the upper triangle (to avoid duplicates)
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Convert the correlation matrix to a long format
corr_df = corr_matrix.stack().reset_index()
corr_df.columns = ['feature1', 'feature2', 'correlation']

# Filter for correlations above a certain threshold (e.g., 0.7)
high_corr_df = corr_df[(abs(corr_df['correlation']) > 0.7) & (corr_df['feature1'] != corr_df['feature2'])]

# Sort by absolute correlation in descending order
high_corr_df = high_corr_df.sort_values(by='correlation', ascending=False, key=abs)

# Print the top correlated features
# print(high_corr_df['feature1'].to_list()[4:10])
print(high_corr_df)
# Out:
#                   feature1               feature2  correlation
# 28           informative_2            duplicate_2     1.000000
# 207            duplicate_1          informative_1     1.000000
# 188            duplicate_2          informative_2     1.000000
# 63           informative_1            duplicate_1     1.000000
# 284                 target            duplicate_1     0.986673
# 220            duplicate_1                 target     0.986673
# 275                 target          informative_1     0.985741
# 67           informative_1                 target     0.985741
# 176    multicollinearity 4    multicollinearity 3     0.901223
# 112    multicollinearity 3    multicollinearity 4     0.901223
# 153    multicollinearity 2    multicollinearity 1     0.723106
# 9      multicollinearity 1    multicollinearity 2     0.723106
# 206            duplicate_1         uniform corr 1     0.719379
# 46          uniform corr 1            duplicate_1     0.719379
# 50          uniform corr 1                 target     0.714299
# 274                 target         uniform corr 1     0.714299
# 97          uniform corr 2            duplicate_1     0.714128
# 209            duplicate_1         uniform corr 2     0.714128
# 101         uniform corr 2                 target     0.712506
# 277                 target         uniform corr 2     0.712506
# 53           informative_1         uniform corr 1     0.704580
# 37          uniform corr 1          informative_1     0.704580
# 84   correlated w target 2                 target     0.703594
# 276                 target  correlated w target 2     0.703594
# 88          uniform corr 2          informative_1     0.703547
# 56           informative_1         uniform corr 2     0.703547

# %%
# check for vif
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# handle null values (using mean imputation for simplicity)
x_copy = df.drop('target', axis=1)._get_numeric_data()
x_copy.fillna(x_copy.mean(), inplace=True)

print(max([variance_inflation_factor(x_copy, i) for i in range(x_copy.shape[1])]))

# calculate VIF
vif = pd.DataFrame()
vif["Variable"] = x_copy.columns
vif["VIF"] = [variance_inflation_factor(x_copy, i) for i in range(x_copy.shape[1])]
print(vif)
# Out:
# 14.836742329171313
#                  Variable        VIF
# 0     multicollinearity 1   1.967201
# 1           informative_2   2.127510
# 2          uniform corr 1   7.512473
# 3           informative_1   4.371354
# 4   correlated w target 2   1.998726
# 5          uniform corr 2   7.362803
# 6     multicollinearity 3   2.604308
# 7   correlated w target 1   1.323104
# 8         min max scaling  12.318077
# 9     multicollinearity 2   1.953081
# 10    multicollinearity 4   2.597018
# 11            duplicate_2   2.064483
# 12            duplicate_1   2.096307
# 13             outliers 1   1.006618
# 14       standard scaling  14.836742
# 15             outliers 2   3.405431

# %% [markdown]
# ## Multicollinearity
#
# * We want high correlation with target
# * We don't want high correlation between features
# * Drop correlated features
# * Combine correlated features

# %%
# # create a new variable by combining two variables
# df['scaling_combined'] = df['standard scaling'] + df['min max scaling']
# df.drop(['standard scaling', 'min max scaling'], axis=1, inplace=True)

# %%
# iterate dropping features with high vif
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

removed1=[]
x_copy1 = x_copy.copy()
max_vif = thresh = 10
while max_vif >= thresh:
  my_list = [variance_inflation_factor(x_copy1, i) for i in range(x_copy1.shape[1])]
  max_vif = max(my_list)
  if max_vif > thresh:
    max_index = my_list.index(max_vif)
    removed1.append(x_copy1.columns[max_index])
    print(x_copy1.columns[max_index], variance_inflation_factor(x_copy1, max_index))
    x_copy1.drop(x_copy1.columns[max_index], axis=1, inplace=True)


# Calculate VIF
vif = pd.DataFrame()
vif["Variable"] = x_copy1.columns
vif["VIF"] = [variance_inflation_factor(x_copy1, i) for i in range(x_copy1.shape[1])]
print(vif)
# Out:
# standard scaling 14.836742329171313
#                  Variable       VIF
# 0     multicollinearity 1  1.967121
# 1           informative_2  2.127356
# 2          uniform corr 1  6.738535
# 3           informative_1  4.070269
# 4   correlated w target 2  1.998693
# 5          uniform corr 2  6.614394
# 6     multicollinearity 3  2.602510
# 7   correlated w target 1  1.322624
# 8         min max scaling  8.392769
# 9     multicollinearity 2  1.950702
# 10    multicollinearity 4  2.593883
# 11            duplicate_2  2.064096
# 12            duplicate_1  2.094359
# 13             outliers 1  1.006604
# 14             outliers 2  3.346583

# %%
# check again vif
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

removed2=[]
max_vif = thresh = 10
while max_vif >= thresh:
  max_vif = max([variance_inflation_factor(x_copy, i) for i in range(x_copy.shape[1])])
  for i in range(x_copy.shape[1]):
    if variance_inflation_factor(x_copy, i) > thresh:
      removed2.append(x_copy.columns[i])
      print(x_copy.columns[i], variance_inflation_factor(x_copy, i))
      x_copy.drop(x_copy.columns[i], axis=1, inplace=True)
      break

# Calculate VIF
vif = pd.DataFrame()
vif["Variable"] = x_copy.columns
vif["VIF"] = [variance_inflation_factor(x_copy, i) for i in range(x_copy.shape[1])]
print(vif)
# Out:
# min max scaling 12.318076656440418
# standard scaling 10.10883102593282
#                  Variable       VIF
# 0     multicollinearity 1  1.967076
# 1           informative_2  2.103541
# 2          uniform corr 1  5.222613
# 3           informative_1  3.443892
# 4   correlated w target 2  1.998676
# 5          uniform corr 2  5.010929
# 6     multicollinearity 3  2.599213
# 7   correlated w target 1  1.319795
# 8     multicollinearity 2  1.950565
# 9     multicollinearity 4  2.593861
# 10            duplicate_2  2.064033
# 11            duplicate_1  2.094328
# 12             outliers 1  1.006564
# 13             outliers 2  3.068629

# %%
print(removed1)
print(removed2)
# Out:
# ['standard scaling']
# ['min max scaling', 'standard scaling']

# %% [markdown]
# ## Outliers

# %%
# code along
df.boxplot(column=['outliers 1']);

# %%
# code along
df.describe()
# Out:
#        multicollinearity 1  informative_2  uniform corr 1  informative_1  \
# count           960.000000    1010.000000      960.000000    1010.000000
# mean              0.029695       0.055164        0.518179       0.028552
# std               0.959900       1.011382        0.287390       0.960630
# min              -3.503529      -2.940389        0.000004      -3.241267
# 25%              -0.626512      -0.651018        0.284547      -0.612270
# 50%               0.047986       0.047742        0.523770       0.033044
# 75%               0.684004       0.708842        0.761058       0.644713
# max               3.086014       3.852731        0.998832       3.078881
#
#        correlated w target 2  uniform corr 2  multicollinearity 3  \
# count            1010.000000      809.000000           809.000000
# mean                0.216406        0.500905            -0.022123
# std                40.100708        0.283345             1.009870
# min              -144.216937        0.000289            -3.258248
# 25%               -26.633109        0.247196            -0.624833
# 50%                 0.073679        0.489106            -0.041765
# 75%                29.285625        0.743316             0.589218
# max               144.653205        0.999726             3.407495
#
#        correlated w target 1  min max scaling  multicollinearity 2  \
# count             958.000000       808.000000          1010.000000
# mean                2.283942       355.136502            -0.012100
# std                39.550484        99.364519             1.024148
# min              -130.809502        16.114250            -3.422676
# 25%               -22.815420       286.875452            -0.684912
# 50%                 2.738624       353.276079            -0.008328
# 75%                29.110427       427.566112             0.649888
# max               135.470506       616.670948             3.663940
#
#        multicollinearity 4  duplicate_2  duplicate_1  outliers 1  \
# count           960.000000   504.000000   503.000000  705.000000
# mean             -0.042008     0.105639     0.110187   -0.017231
# std               1.000213     1.007419     0.971004    1.326761
# min              -3.902912    -2.940389    -2.703232   -5.243786
# 25%              -0.664090    -0.585201    -0.567713   -0.725405
# 50%              -0.102868     0.129981     0.064280    0.007270
# 75%               0.617020     0.809421     0.731781    0.708124
# max               3.720667     3.193108     2.644343    4.529606
#
#        standard scaling  outliers 2       target
# count       1010.000000  809.000000  1010.000000
# mean       49973.134342    3.182666     1.526969
# std        10543.524707    2.234375    39.692008
# min        17052.410208   -5.045730  -138.656882
# 25%        43121.491790    1.714250   -24.151319
# 50%        49934.695106    3.199192     0.760906
# 75%        56621.277628    4.726593    27.054058
# max        86405.565179   10.187384   132.791973

# %%
# code along
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1010 entries, 0 to 9
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   binary                 505 non-null    object
#  1   given_name             909 non-null    object
#  2   surname                710 non-null    object
#  3   date_of_birth          705 non-null    object
#  4   phone_number           958 non-null    object
#  5   email                  1010 non-null   object
#  6   address                909 non-null    object
#  7   city                   502 non-null    object
#  8   state                  707 non-null    object
#  9   zipcode                705 non-null    object
#  10  multicollinearity 1    960 non-null    float64
#  11  random label num 3     505 non-null    object
#  12  informative_2          1010 non-null   float64
#  13  random label num 12    1010 non-null   object
#  14  uniform corr 1         960 non-null    float64
#  15  informative_1          1010 non-null   float64
#  16  correlated w target 2  1010 non-null   float64
#  17  uniform corr 2         809 non-null    float64
#  18  multicollinearity 3    809 non-null    float64
#  19  constant_2             1010 non-null   object
#  20  random choice 7        807 non-null    object
#  21  correlated w target 1  958 non-null    float64
#  22  min max scaling        808 non-null    float64
#  23  multicollinearity 2    1010 non-null   float64
#  24  pd qcut2               504 non-null    category
#  25  multicollinearity 4    960 non-null    float64
#  26  duplicate_2            504 non-null    float64
#  27  pd qcut3               910 non-null    category
#  28  duplicate_1            503 non-null    float64
#  29  outliers 1             705 non-null    float64
#  30  standard scaling       1010 non-null   float64
#  31  pd qcut1               1010 non-null   category
#  32  semi_constant_2        1010 non-null   object
#  33  semi_constant_1        1010 non-null   object
#  34  random choice 4        909 non-null    object
#  35  random choice 2        960 non-null    object
#  36  outliers 2             809 non-null    float64
#  37  constant_1             1010 non-null   object
#  38  target                 1010 non-null   float64
# dtypes: category(3), float64(17), object(19)
# memory usage: 295.4+ KB

# %% [markdown]
# ## Data Prep
#
# https://www.udemy.com/course/feature-engineering-for-machine-learning
#
# * Types and characteristics of data
# * Missing data imputation
# * Categorical encoding
# * Variable transformation
# * Discretization
# * Outliers
# * Datetime
# * Scaling
# * Feature creation

# %%
# ! git clone https://github.com/gitmystuff/preppy.git

# %%
# import shutil

# # Source file path (within your Drive)
# source_file = '/content/drive/MyDrive/DTSC5502/Project CICD/preppy report.py'

# # Destination path (root of your Drive)
# destination_path = '/content/preppy/utils/report.py'

# # Copy the file
# shutil.copy(source_file, destination_path)

# %%
import preppy.utils as utils
from preppy.version import __version__

print(__version__)

utils.report.write_report(df, thresh=.5)
# Out:
# PrepPy Version: 0.1.0
# REPORT FOR DATA PREP
#
# #################################################
# Columns with Constant Values
# #################################################
# ['constant_2', 'constant_1']
#
# #################################################
# Columns with Quasi-Constant Values
# #################################################
# ['constant_1', 'constant_2', 'pd qcut1']
#
# #################################################
# Duplicate Rows
# #################################################
# 20
#
# #################################################
# Duplicate Columns
# #################################################
# ['constant_1']
#
# #################################################
# Variables with Noticeably Higher Scales
# #################################################
# Features with Noticeably Higher Scales (Based on Standard Deviation):
# standard scaling    10543.524707
# Name: std, dtype: float64
#
# Features with Noticeably Higher Scales (Based on Range):
# standard scaling    69353.154971
# dtype: float64
# None
#
# #################################################
# Variables with Missing Values
# #################################################
# binary                   505
# given_name               101
# surname                  300
# date_of_birth            305
# phone_number              52
# address                  101
# city                     508
# state                    303
# zipcode                  305
# multicollinearity 1       50
# random label num 3       505
# uniform corr 1            50
# uniform corr 2           201
# multicollinearity 3      201
# random choice 7          203
# correlated w target 1     52
# min max scaling          202
# pd qcut2                 506
# multicollinearity 4       50
# duplicate_2              506
# pd qcut3                 100
# duplicate_1              507
# outliers 1               305
# random choice 4          101
# random choice 2           50
# outliers 2               201
# dtype: int64
#
# #################################################
# Variables that Need Categorical Encoding
# #################################################
# Index(['binary', 'given_name', 'surname', 'date_of_birth', 'phone_number',
#        'email', 'address', 'city', 'state', 'zipcode', 'random label num 3',
#        'random label num 12', 'constant_2', 'random choice 7',
#        'semi_constant_2', 'semi_constant_1', 'random choice 4',
#        'random choice 2', 'constant_1'],
#       dtype='object')
#
# #################################################
# Variables with Outliers
# #################################################
# Column: multicollinearity 1
# Outliers: [-3.5035294880805767, -2.6767995993418894, 2.724660840804588, 3.08601351666607, 2.745188918118217]
# ---
# Column: informative_2
# Outliers: [3.852731490654721, -2.9403886346642802, -2.8962553781936893, -2.8722622132816493, 3.1377485336599937, -2.8485426206300755, -2.9213504834946074, 3.193107567844861]
# ---
# Column: informative_1
# Outliers: [-2.499405714873573, -2.6197451040897444, -3.2412673400690726, -2.553921134901955, -2.6968866429415717, 2.5733598032498604, 3.0788808084552377, -2.5302875227463297, 2.6443433470170348, -2.703232292999237, 2.5600845382687947, -2.650969808393012]
# ---
# Column: correlated w target 2
# Outliers: [118.50881617273917, -144.21693651799322, 144.6532049519236, -115.21192450492197]
# ---
# Column: multicollinearity 3
# Outliers: [-3.258248101408647, 2.6160581098486535, 2.6525799159874883, -2.9370033053900793, 2.415528889007287, 3.0416802010736412, 2.4865441290830117, 2.5300045589430082, -2.570100568040208, 2.9700130840120007, 3.212200020400176, -2.662962919678361, 3.4074951601540295, 2.7750514329643985, 2.420380860934896, -2.8502768529651954, -2.619079577876892, -2.826471714057767, -3.258248101408647]
# ---
# Column: correlated w target 1
# Outliers: [-111.59324958825555, 135.47050644598468, -126.90469779096506, -101.83054971129994, -105.87901562747406, -130.80950214358631, -100.7573311649194, 114.66471673196905]
# ---
# Column: min max scaling
# Outliers: [16.114250084188456, 56.34825907887376, 19.304887341154043]
# ---
# Column: multicollinearity 2
# Outliers: [-3.4226756116200194, -2.847456289438833, -2.878820140803228, 2.700394745765721, -2.8461245446416847, -3.2212271460737307, 3.6639399138365536]
# ---
# Column: multicollinearity 4
# Outliers: [-3.9029121514445286, -2.946505285361748, 3.1577730648522655, 2.8328900790118485, 2.931606201702415, -2.6694484581537488, 3.720667029108192, -2.6621647758704245, 2.5873511771328057, -2.92000350973383, -2.665598103450874, -3.152860801266007, -3.9029121514445286]
# ---
# Column: duplicate_2
# Outliers: [-2.9403886346642802, 3.1377485336599937, -2.9213504834946074, 3.193107567844861]
# ---
# Column: duplicate_1
# Outliers: [-2.6968866429415717, -2.703232292999237, -2.650969808393012]
# ---
# Column: outliers 1
# Outliers: [3.0416381771754653, 3.5760944030868975, -2.87625068355035, -2.890599845360738, -4.3085904956658245, -5.243786392060555, 3.4198922360502166, -4.947397326079663, -3.3954747356523307, -2.916215159772702, -3.0501329172057474, 4.4477320143415655, -3.322303136522664, 3.9040221720065, -3.354868527425585, 3.474325634904649, 2.8927838078788604, -4.862612456125628, 3.836992477336657, -3.052953927144499, -3.172616782632269, -3.807489966215437, 3.6813138876539844, -3.70597111433522, 4.201717275550154, 3.510482958380462, 3.6208026841430376, -3.200219486700641, 2.9752249730862146, 4.116276698241738, 3.938202427845792, 4.529606115292702, -3.067742312009584, -4.968674045271213]
# ---
# Column: standard scaling
# Outliers: [22019.75012919947, 78050.03768370792, 78129.5522940691, 21341.495573291453, 81612.71788467947, 79815.64552096848, 19998.75030078377, 22834.616311734913, 86405.56517863213, 19888.0132788664, 79777.08408620961, 17052.41020763846]
# ---
# Column: outliers 2
# Outliers: [-2.933302071739351, 10.187384227211346, 9.954376952185806, -5.045729645932259, -3.5400339161870296]
# ---
# Column: target
# Outliers: [-101.4030651422634, -138.65688215430066, -105.99126923620545, -110.08353067986067, 105.23895764683351, 132.79197347540796, -104.9234418373767, -105.64247434616566, -102.83161869768337]
# ---
#
# #################################################
# END OF REPORT
# #################################################

# %% [markdown]
# ## Feature Engineering

# %%
df_numerical = df.select_dtypes(include='number').columns
df_object = df.select_dtypes(include=['object']).columns
df_discreet = df.select_dtypes(include=['category']).columns
df_categorical_features = df.select_dtypes(include=['category', 'object']).columns
df_discreet
# Out:
# Index(['pd qcut2', 'pd qcut3', 'pd qcut1'], dtype='object')

# %%
# def handle_missing_values(df):
#   df_categorical_features = df.select_dtypes(include=['category', 'object']).columns
#   dfx = df.copy()
#   for feat in df.columns[df.isnull().sum() > 1]:
#     if feat in df_categorical_features:
#       dfx[feat] = df[feat].fillna(df[feat].mode()[0])
#     else:
#       if abs(df[feat].skew()) < .8:
#         dfx[feat] = df[feat].fillna(round(df[feat].mean(), 2))
#       else:
#         dfx[feat] = df[feat].fillna(df[feat].median())

#   return dfx

# df = handle_missing_values(df)
# df.info()

# %% [markdown]
# ## Pipelines

# %% [markdown]
# ## BaseEstimator, TransformerMixin
#
# Imagine you're building a machine to process and transform data. `BaseEstimator` and `TransformerMixin` are like instruction manuals that help your machine understand how to work with different parts of the data.
#
# **`BaseEstimator`**
#
# *   Provides basic tools:** This is like a toolbox with essential tools for your machine. It provides methods for getting and setting parameters (like knobs and switches on your machine) and for cloning the machine (making a copy of it).
#
# **`TransformerMixin`**
#
# *   Handles transformations:** This manual teaches your machine how to transform data. It provides a method called `fit_transform` that combines two steps:
#     *   **`fit`:**  The machine learns something about the data (like figuring out the average value).
#     *   **`transform`:** The machine uses what it learned to change the data (like subtracting the average value from each data point).
#
# **Why use them with pipeline transformers?**
#
# *   **Compatibility:** When you build custom transformers (special parts for your machine) and want to use them in a scikit-learn pipeline (a series of connected machines), inheriting from `BaseEstimator` and `TransformerMixin` ensures that your custom parts fit seamlessly with the other machines in the pipeline.
# *   **Convenience:** `TransformerMixin` provides the handy `fit_transform` method, which streamlines the process of fitting and transforming data in one step.
#
# **In simple terms**
#
# `BaseEstimator` and `TransformerMixin` are like blueprints that help you build standardized and compatible parts for your data processing machine (pipeline), making it easier to manage and transform your data.

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import inspect

print(dir(BaseEstimator))
print(dir(TransformerMixin))

print(BaseEstimator.__dict__)

print(inspect.getmembers(BaseEstimator))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__sklearn_clone__', '__str__', '__subclasshook__', '__weakref__', '_build_request_for_signature', '_check_feature_names', '_check_n_features', '_doc_link_module', '_doc_link_template', '_doc_link_url_param_generator', '_get_default_requests', '_get_doc_link', '_get_metadata_request', '_get_param_names', '_get_tags', '_more_tags', '_repr_html_', '_repr_html_inner', '_repr_mimebundle_', '_validate_data', '_validate_params', 'get_metadata_routing', 'get_params', 'set_params']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_sklearn_auto_wrap_output_keys', 'fit_transform', 'set_output']
# {'__module__': 'sklearn.base', '__doc__': "Base class for all estimators in scikit-learn.\n\n    Inheriting from this class provides default implementations of:\n\n    - setting and getting parameters used by `GridSearchCV` and friends;\n    - textual and HTML representation displayed in terminals and IDEs;\n    - estimator serialization;\n    - parameters validation;\n    - data validation;\n    - feature names validation.\n\n    Read more in the :ref:`User Guide <rolling_your_own_estimator>`.\n\n\n    Notes\n    -----\n    All estimators should specify all the parameters that can be set\n    at the class level in their ``__init__`` as explicit keyword\n    arguments (no ``*args`` or ``**kwargs``).\n\n    Examples\n    --------\n    >>> import numpy as np\n    >>> from sklearn.base import BaseEstimator\n    >>> class MyEstimator(BaseEstimator):\n    ...     def __init__(self, *, param=1):\n    ...         self.param = param\n    ...     def fit(self, X, y=None):\n    ...         self.is_fitted_ = True\n    ...         return self\n    ...     def predict(self, X):\n    ...         return np.full(shape=X.shape[0], fill_value=self.param)\n    >>> estimator = MyEstimator(param=2)\n    >>> estimator.get_params()\n    {'param': 2}\n    >>> X = np.array([[1, 2], [2, 3], [3, 4]])\n    >>> y = np.array([1, 0, 1])\n    >>> estimator.fit(X, y).predict(X)\n    array([2, 2, 2])\n    >>> estimator.set_params(param=3).fit(X, y).predict(X)\n    array([3, 3, 3])\n    ", '_get_param_names': <classmethod(<function BaseEstimator._get_param_names at 0x7d5433117760>)>, 'get_params': <function BaseEstimator.get_params at 0x7d54331177f0>, 'set_params': <function BaseEstimator.set_params at 0x7d5433117880>, '__sklearn_clone__': <function BaseEstimator.__sklearn_clone__ at 0x7d5433117910>, '__repr__': <function BaseEstimator.__repr__ at 0x7d54331179a0>, '__getstate__': <function BaseEstimator.__getstate__ at 0x7d5433117a30>, '__setstate__': <function BaseEstimator.__setstate__ at 0x7d5433117ac0>, '_more_tags': <function BaseEstimator._more_tags at 0x7d5433117b50>, '_get_tags': <function BaseEstimator._get_tags at 0x7d5433117be0>, '_check_n_features': <function BaseEstimator._check_n_features at 0x7d5433117c70>, '_check_feature_names': <function BaseEstimator._check_feature_names at 0x7d5433117d00>, '_validate_data': <function BaseEstimator._validate_data at 0x7d5433117d90>, '_validate_params': <function BaseEstimator._validate_params at 0x7d5433117e20>, '_repr_html_': <property object at 0x7d546fbc2930>, '_repr_html_inner': <function BaseEstimator._repr_html_inner at 0x7d5433117f40>, '_repr_mimebundle_': <function BaseEstimator._repr_mimebundle_ at 0x7d5433128040>}
# [('__class__', <class 'type'>), ('__delattr__', <slot wrapper '__delattr__' of 'object' objects>), ('__dict__', mappingproxy({'__module__': 'sklearn.base', '__doc__': "Base class for all estimators in scikit-learn.\n\n    Inheriting from this class provides default implementations of:\n\n    - setting and getting parameters used by `GridSearchCV` and friends;\n    - textual and HTML representation displayed in terminals and IDEs;\n    - estimator serialization;\n    - parameters validation;\n    - data validation;\n    - feature names validation.\n\n    Read more in the :ref:`User Guide <rolling_your_own_estimator>`.\n\n\n    Notes\n    -----\n    All estimators should specify all the parameters that can be set\n    at the class level in their ``__init__`` as explicit keyword\n    arguments (no ``*args`` or ``**kwargs``).\n\n    Examples\n    --------\n    >>> import numpy as np\n    >>> from sklearn.base import BaseEstimator\n    >>> class MyEstimator(BaseEstimator):\n    ...     def __init__(self, *, param=1):\n    ...         self.param = param\n    ...     def fit(self, X, y=None):\n    ...         self.is_fitted_ = True\n    ...         return self\n    ...     def predict(self, X):\n    ...         return np.full(shape=X.shape[0], fill_value=self.param)\n    >>> estimator = MyEstimator(param=2)\n    >>> estimator.get_params()\n    {'param': 2}\n    >>> X = np.array([[1, 2], [2, 3], [3, 4]])\n    >>> y = np.array([1, 0, 1])\n    >>> estimator.fit(X, y).predict(X)\n    array([2, 2, 2])\n    >>> estimator.set_params(param=3).fit(X, y).predict(X)\n    array([3, 3, 3])\n    ", '_get_param_names': <classmethod(<function BaseEstimator._get_param_names at 0x7d5433117760>)>, 'get_params': <function BaseEstimator.get_params at 0x7d54331177f0>, 'set_params': <function BaseEstimator.set_params at 0x7d5433117880>, '__sklearn_clone__': <function BaseEstimator.__sklearn_clone__ at 0x7d5433117910>, '__repr__': <function BaseEstimator.__repr__ at 0x7d54331179a0>, '__getstate__': <function BaseEstimator.__getstate__ at 0x7d5433117a30>, '__setstate__': <function BaseEstimator.__setstate__ at 0x7d5433117ac0>, '_more_tags': <function BaseEstimator._more_tags at 0x7d5433117b50>, '_get_tags': <function BaseEstimator._get_tags at 0x7d5433117be0>, '_check_n_features': <function BaseEstimator._check_n_features at 0x7d5433117c70>, '_check_feature_names': <function BaseEstimator._check_feature_names at 0x7d5433117d00>, '_validate_data': <function BaseEstimator._validate_data at 0x7d5433117d90>, '_validate_params': <function BaseEstimator._validate_params at 0x7d5433117e20>, '_repr_html_': <property object at 0x7d546fbc2930>, '_repr_html_inner': <function BaseEstimator._repr_html_inner at 0x7d5433117f40>, '_repr_mimebundle_': <function BaseEstimator._repr_mimebundle_ at 0x7d5433128040>})), ('__dir__', <method '__dir__' of 'object' objects>), ('__doc__', "Base class for all estimators in scikit-learn.\n\n    Inheriting from this class provides default implementations of:\n\n    - setting and getting parameters used by `GridSearchCV` and friends;\n    - textual and HTML representation displayed in terminals and IDEs;\n    - estimator serialization;\n    - parameters validation;\n    - data validation;\n    - feature names validation.\n\n    Read more in the :ref:`User Guide <rolling_your_own_estimator>`.\n\n\n    Notes\n    -----\n    All estimators should specify all the parameters that can be set\n    at the class level in their ``__init__`` as explicit keyword\n    arguments (no ``*args`` or ``**kwargs``).\n\n    Examples\n    --------\n    >>> import numpy as np\n    >>> from sklearn.base import BaseEstimator\n    >>> class MyEstimator(BaseEstimator):\n    ...     def __init__(self, *, param=1):\n    ...         self.param = param\n    ...     def fit(self, X, y=None):\n    ...         self.is_fitted_ = True\n    ...         return self\n    ...     def predict(self, X):\n    ...         return np.full(shape=X.shape[0], fill_value=self.param)\n    ...

# %%
import pprint

pprint.pprint(inspect.getmembers(BaseEstimator))
# Out:
# [('__class__', <class 'type'>),
#  ('__delattr__', <slot wrapper '__delattr__' of 'object' objects>),
#  ('__dict__',
#   mappingproxy({'__doc__': 'Base class for all estimators in scikit-learn.\n'
#                            '\n'
#                            '    Inheriting from this class provides default '
#                            'implementations of:\n'
#                            '\n'
#                            '    - setting and getting parameters used by '
#                            '`GridSearchCV` and friends;\n'
#                            '    - textual and HTML representation displayed in '
#                            'terminals and IDEs;\n'
#                            '    - estimator serialization;\n'
#                            '    - parameters validation;\n'
#                            '    - data validation;\n'
#                            '    - feature names validation.\n'
#                            '\n'
#                            '    Read more in the :ref:`User Guide '
#                            '<rolling_your_own_estimator>`.\n'
#                            '\n'
#                            '\n'
#                            '    Notes\n'
#                            '    -----\n'
#                            '    All estimators should specify all the '
#                            'parameters that can be set\n'
#                            '    at the class level in their ``__init__`` as '
#                            'explicit keyword\n'
#                            '    arguments (no ``*args`` or ``**kwargs``).\n'
#                            '\n'
#                            '    Examples\n'
#                            '    --------\n'
#                            '    >>> import numpy as np\n'
#                            '    >>> from sklearn.base import BaseEstimator\n'
#                            '    >>> class MyEstimator(BaseEstimator):\n'
#                            '    ...     def __init__(self, *, param=1):\n'
#                            '    ...         self.param = param\n'
#                            '    ...     def fit(self, X, y=None):\n'
#                            '    ...         self.is_fitted_ = True\n'
#                            '    ...         return self\n'
#                            '    ...     def predict(self, X):\n'
#                            '    ...         return np.full(shape=X.shape[0], '
#                            'fill_value=self.param)\n'
#                            '    >>> estimator = MyEstimator(param=2)\n'
#                            '    >>> estimator.get_params()\n'
#                            "    {'param': 2}\n"
#                            '    >>> X = np.array([[1, 2], [2, 3], [3, 4]])\n'
#                            '    >>> y = np.array([1, 0, 1])\n'
#                            '    >>> estimator.fit(X, y).predict(X)\n'
#                            '    array([2, 2, 2])\n'
#                            '    >>> estimator.set_params(param=3).fit(X, '
#                            'y).predict(X)\n'
#                            '    array([3, 3, 3])\n'
#                            '    ',
#                 '__getstate__': <function BaseEstimator.__getstate__ at 0x7d5433117a30>,
#                 '__module__': 'sklearn.base',
#                 '__repr__': <function BaseEstimator.__repr__ at 0x7d54331179a0>,
#                 '__setstate__': <function BaseEstimator.__setstate__ at 0x7d5433117ac0>,
#                 '__sklearn_clone__': <function BaseEstimator.__sklearn_clone__ at 0x7d5433117910>,
#                 '_check_feature_names': <function BaseEstimator._check_feature_names at 0x7d5433117d00>,
#                 '_check_n_features': <function BaseEstimator._check_n_features at 0x7d5433117c70>,
#                 '_get_param_names': <classmethod(<function BaseEstimator._get_param_names at 0x7d5433117760>)>,
#                 '_get_tags': <function BaseEstimator._get_tags at 0x7d5433117be0>,
#                 '_more_tags': <function BaseEstimator._more_tags at 0x7d5433117b50>,
#                 '_repr_html_': <property object at 0x7d546fbc2930>,
#                 '_repr_html_inner': <function BaseEstimator._repr_html_inner at 0x7d5433117f40>,
#                 '_repr_mimebundle_': <function BaseEstimator._repr_mimebundle_ at 0x7d5433128040>,
#                 '_validate_data': <function BaseEstimator._validate_data at 0x7d5433117d90>,
#                 '_validate_params': <function BaseEstimator._validate_params at 0x7d5433117e20>,
#                 'get_params': <function BaseEstimator.get_params at 0x7d54331177f0>,
#                 'set_params': <function BaseEstimator.set_params at 0x7d5433117880>})),
#  ('__dir__', <method '__dir__' of 'object' objects>),
#  ('__doc__',
#   'Base class for all estimators in scikit-learn.\n'
#   '\n'
#   '    Inheriting from this class provides default implementations of:\n'
#   '\n'
#   '    - setting and getting parameters used by `GridSearchCV` and friends;\n'
#   '    - textual and HTML representation displayed in terminals and IDEs;\n'
#   '    - estimator serialization;\n'
#   '    - parameters validation;\n'
#   '    - data validation;\n'
#   '    - feature names validation.\n'
#   '\n'
#   '    Read more in the :ref:`User Guide <rolling_your_own_estimator>`.\n'
#   '\n'
#   '\n'
#   '    Notes\n'
#   '    -----\n'
#   '    All estimators should specify all the parameters that can be set\n'
#   '    at the class level in their ``__init__`` as explicit keyword\n'
#   '    arguments (no ``*args`` or ``**kwargs``).\n'
#   '\n'
#   '    Examples\n'
#   '    --------\n'
#   '    >>> import numpy as np\n'
#   '    >>> from sklearn.base import BaseEstimator\n'
#   '    >>> class MyEstimator(BaseEstimator):\n'
#   '    ...     def __init__(self, *, param=1):\n'
#   '    ...         self.param = param\n'
#   '    ...     def fit(self, X, y=None):\n'
#   '    ...         self.is_fitted_ = True\n'
#   '    ...         return self\n'
#   '    ...     def predict(self, X):\n'
#   '    ...         return np.full(shape=X.shape[0], fill_value=self.param)\n'
#   '    >>> estimator = MyEstimator(param=2)\n'
#   '    >>> estimator.get_params()\n'
#   "    {'param': 2}\n"
#   '    >>> X = np.array([[1, 2], [2, 3], [3, 4]])\n'
#   '    >>> y = np.array([1, 0, 1])\n'
#   '    >>> estimator.fit(X, y).predict(X)\n'
#   '    array([2, 2, 2])\n'
#   '    >>> estimator.set_params(param=3).fit(X, y).predict(X)\n'
#   '    array([3, 3, 3])\n'
#   '    '),
#  ('__eq__', <slot wrapper '__eq__' of 'object' objects>),
#  ('__format__', <method '__format__' of 'object' objects>),
#  ('__ge__', <slot wrapper '__ge__' of 'object' objects>),
#  ('__getattribute__', <slot wrapper '__getattribute__' of 'object' objects>),
#  ('__getstate__', <function BaseEstimator.__getstate__ at 0x7d5433117a30>),
#  ('__gt__', <slot wrapper '__gt__' of 'object' objects>),
#  ('__hash__', <slot wrapper '__hash__' of 'object' objects>),
#  ('__init__', <slot wrapper '__init__' of 'object' objects>),
#  ('__init_subclass__',
#   <bound method _MetadataRequester.__init_subclass__ of <class 'sklearn.base.BaseEstimator'>>),
#  ('__le__', <slot wrapper '__le__' of 'object' objects>),
#  ('__lt__', <slot wrapper '__lt__' of 'object' objects>),
#  ('__module__', 'sklearn.base'),
#  ('__ne__', <slot wrapper '__ne__' of 'object' objects>),
#  ('__new__', <built-in method __new__ of type object at 0x5d0392366800>),
#  ('__reduce__', <method '__reduce__' of 'object' objects>),
#  ('__reduce_ex__', <method '__reduce_ex__' of 'object' objects>),
#  ('__repr__', <function BaseEstimator.__repr__ at 0x7d54331179a0>),
#  ('__setattr__', <slot wrapper '__setattr__' of 'object' objects>),
#  ('__setstate__', <function BaseEstimator.__setstate__ at 0x7d5433117ac0>),
#  ('__sizeof__', <method '__sizeof__' of 'object' objects>),
#  ('__sklearn_clone__',
#   <function BaseEstimator.__sklearn_clone__ at 0x7d5433117910>),
#  ('__str__', <slot wrapper '__str__' of 'object' objects>),
#  ('__subclasshook__',
#   <built-in method __subclasshook__ of type object at 0x5d0394b9ba10>),
#  ('__weakref__',
#   <attribute '__weakref__' of '_HTMLDocumentationLinkMixin' objects>),
#  ('_build_request_for_signature',
#   <bound method _MetadataRequester._build_request_for_signature of <class 'sklearn.base.BaseEstimator'>>),
#  ('_check_feature_names',
#   <function BaseEstimator._check_feature_names at 0x7d5433117d00>),
#  ('_check_n_features',
#   <function BaseEstimator._check_n_features at 0x7d5433117c70>),
#  ('_doc_link_module', 'sklearn'),
#  ('_doc_link_template', <property object at 0x7d54330de5c0>),
#  ('_doc_link_url_param_generator', None),
#  ('_get_default_requests',
#   <bound method _MetadataRequester._get_default_requests of <class 'sklearn.base.BaseEstimator'>>),
#  ('_get_doc_link',
#   <function _HTMLDocumentationLinkMixin._get_doc_link at 0x7d54330e6b00>),
#  ('_get_metadata_request',
#   <function _MetadataRequester._get_metadata_request at 0x7d546fae27a0>),
#  ('_get_param_names',
#   <bound method BaseEstimator._get_param_names of <class 'sklearn.base.BaseEstimator'>>),
#  ('_get_tags', <function BaseEstimator._get_tags at 0x7d5433117be0>),
#  ('_more_tags', <function BaseEstimator._more_tags at 0x7d5433117b50>),
#  ('_repr_html_', <property object at 0x7d546fbc2930>),
#  ('_repr_html_inner',
#   <function BaseEstimator._repr_html_inner at 0x7d5433117f40>),
#  ('_repr_mimebundle_',
#   <function BaseEstimator._repr_mimebundle_ at 0x7d5433128040>),
#  ('_validate_data', <function BaseEstimator._validate_data at 0x7d5433117d90>),
#  ('_validate_params',
#   <function BaseEstimator._validate_params at 0x7d5433117e20>),
#  ('get_metadata_routing',
#   <function _MetadataRequester.get_metadata_routing at 0x7d546fae2830>),
#  ('get_params', <function BaseEstimator.get_params at 0x7d54331177f0>),
#  ('set_params', <function BaseEstimator.set_params at 0x7d5433117880>)]

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
import preppy.utils as preppy

df.drop(['constant_1', 'constant_2'], axis=1, inplace=True)

class DropDuplicates(BaseEstimator, TransformerMixin):
  def __init__(self):
    pass

  def fit(self, X, y=None):
    return self

  def transform(self, X):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)

    X.drop_duplicates(inplace=True) # drop duplicate rows
    vars = preppy.functions.check_col_duplicates(X)
    X.drop(vars, axis=1, inplace=True) # drop duplicate columns
    return X.values

class HandleMissingValues(BaseEstimator, TransformerMixin):
  def __init__(self):
    pass

  def fit(self, X, y=None):
    return self

  def transform(self, X):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)

    X = preppy.functions.handle_missing_values(X)
    return X.values

class HandleCatEncodeing(BaseEstimator, TransformerMixin):
  def __init__(self):
    pass

  def fit(self, X, y=None):
    return self

  def transform(self, X):
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)

    X = preppy.functions.do_OHE(X)
    return X.values

pipe = [
    ('constants', preppy.classes.RemoveConstants()),
    ('quasiconsts', preppy.classes.RemoveQuasiConstants(thresh=0.8)),
    ('duplicates', DropDuplicates()),
    ('missing', HandleMissingValues()),
    # ('encoding', HandleCatEncodeing())
]

pipe_model = Pipeline(pipe)
data = pipe_model.fit_transform(df)
nu_df = pd.DataFrame(data, columns=df.columns)
nu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   binary                 1000 non-null   object
#  1   given_name             1000 non-null   object
#  2   surname                1000 non-null   object
#  3   date_of_birth          1000 non-null   object
#  4   phone_number           1000 non-null   object
#  5   email                  1000 non-null   object
#  6   address                1000 non-null   object
#  7   city                   1000 non-null   object
#  8   state                  1000 non-null   object
#  9   zipcode                1000 non-null   object
#  10  multicollinearity 1    1000 non-null   object
#  11  random label num 3     1000 non-null   object
#  12  informative_2          1000 non-null   object
#  13  random label num 12    1000 non-null   object
#  14  uniform corr 1         1000 non-null   object
#  15  informative_1          1000 non-null   object
#  16  correlated w target 2  1000 non-null   object
#  17  uniform corr 2         1000 non-null   object
#  18  multicollinearity 3    1000 non-null   object
#  19  random choice 7        1000 non-null   object
#  20  correlated w target 1  1000 non-null   object
#  21  min max scaling        1000 non-null   object
#  22  multicollinearity 2    1000 non-null   object
#  23  pd qcut2               1000 non-null   object
#  24  multicollinearity 4    1000 non-null   object
#  25  duplicate_2            1000 non-null   object
#  26  pd qcut3               1000 non-null   object
#  27  duplicate_1            1000 non-null   object
#  28  outliers 1             1000 non-null   object
#  29  standard scaling       1000 non-null   object
#  30  pd qcut1               1000 non-null   object
#  31  semi_constant_2        1000 non-null   object
#  32  semi_constant_1        1000 non-null   object
#  33  random choice 4        1000 non-null   object
#  34  random choice 2        1000 non-null   object
#  35  outliers 2             1000 non-null   object
#  36  target                 1000 non-null   object
# dtypes: object(37)
# memory usage: 289.2+ KB
# /content/preppy/utils/functions.py:61: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfx[feat] = df[feat].fillna(df[feat].mode()[0])

# %%
# code along
nu_df[df_numerical] = nu_df[df_numerical].astype(float)
nu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   binary                 1000 non-null   object
#  1   given_name             1000 non-null   object
#  2   surname                1000 non-null   object
#  3   date_of_birth          1000 non-null   object
#  4   phone_number           1000 non-null   object
#  5   email                  1000 non-null   object
#  6   address                1000 non-null   object
#  7   city                   1000 non-null   object
#  8   state                  1000 non-null   object
#  9   zipcode                1000 non-null   object
#  10  multicollinearity 1    1000 non-null   float64
#  11  random label num 3     1000 non-null   object
#  12  informative_2          1000 non-null   float64
#  13  random label num 12    1000 non-null   object
#  14  uniform corr 1         1000 non-null   float64
#  15  informative_1          1000 non-null   float64
#  16  correlated w target 2  1000 non-null   float64
#  17  uniform corr 2         1000 non-null   float64
#  18  multicollinearity 3    1000 non-null   float64
#  19  random choice 7        1000 non-null   object
#  20  correlated w target 1  1000 non-null   float64
#  21  min max scaling        1000 non-null   float64
#  22  multicollinearity 2    1000 non-null   float64
#  23  pd qcut2               1000 non-null   object
#  24  multicollinearity 4    1000 non-null   float64
#  25  duplicate_2            1000 non-null   float64
#  26  pd qcut3               1000 non-null   object
#  27  duplicate_1            1000 non-null   float64
#  28  outliers 1             1000 non-null   float64
#  29  standard scaling       1000 non-null   float64
#  30  pd qcut1               1000 non-null   object
#  31  semi_constant_2        1000 non-null   object
#  32  semi_constant_1        1000 non-null   object
#  33  random choice 4        1000 non-null   object
#  34  random choice 2        1000 non-null   object
#  35  outliers 2             1000 non-null   float64
#  36  target                 1000 non-null   float64
# dtypes: float64(17), object(20)
# memory usage: 289.2+ KB

# %% [markdown]
# ## Categorical Encoding

# %%
# code along
import preppy.utils as utils

nu_df = utils.functions.do_OHE(nu_df)
nu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   binary                             1000 non-null   int64
#  1   given_name                         1000 non-null   float64
#  2   surname                            1000 non-null   float64
#  3   date_of_birth                      1000 non-null   float64
#  4   phone_number                       1000 non-null   float64
#  5   email                              1000 non-null   float64
#  6   address                            1000 non-null   float64
#  7   city                               1000 non-null   float64
#  8   state                              1000 non-null   float64
#  9   zipcode                            1000 non-null   float64
#  10  multicollinearity 1                1000 non-null   float64
#  11  informative_2                      1000 non-null   float64
#  12  random label num 12                1000 non-null   float64
#  13  uniform corr 1                     1000 non-null   float64
#  14  informative_1                      1000 non-null   float64
#  15  correlated w target 2              1000 non-null   float64
#  16  uniform corr 2                     1000 non-null   float64
#  17  multicollinearity 3                1000 non-null   float64
#  18  random choice 7                    1000 non-null   float64
#  19  correlated w target 1              1000 non-null   float64
#  20  min max scaling                    1000 non-null   float64
#  21  multicollinearity 2                1000 non-null   float64
#  22  multicollinearity 4                1000 non-null   float64
#  23  duplicate_2                        1000 non-null   float64
#  24  pd qcut3                           1000 non-null   float64
#  25  duplicate_1                        1000 non-null   float64
#  26  outliers 1                         1000 non-null   float64
#  27  standard scaling                   1000 non-null   float64
#  28  pd qcut1                           1000 non-null   int64
#  29  random choice 2                    1000 non-null   int64
#  30  outliers 2                         1000 non-null   float64
#  31  target                             1000 non-null   float64
#  32  random label num 3_label num lo 2  1000 non-null   float64
#  33  random label num 3_label num lo 3  1000 non-null   float64
#  34  pd qcut2_Q2                        1000 non-null   float64
#  35  pd qcut2_Q3                        1000 non-null   float64
#  36  pd qcut2_Q4                        1000 non-null   float64
#  37  semi_constant_2_q_const_0_1        1000 non-null   float64
#  38  semi_constant_2_q_const_0_2        1000 non-null   float64
#  39  semi_constant_1_q_const_0_1        1000 non-null   float64
#  40  semi_constant_1_q_const_0_2        1000 non-null   float64
#  41  random choice 4_North              1000 non-null   float64
#  42  random choice 4_South              1000 non-null   float64
#  43  random choice 4_West               1000 non-null   float64
# dtypes: float64(41), int64(3)
# memory usage: 343.9 KB

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ## Model Fine-Tuning

# %% [markdown]
# ## Model Deployment
