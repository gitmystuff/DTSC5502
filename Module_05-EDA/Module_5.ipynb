# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC5502/blob/main/Module_05-EDA/Module_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Life Spans
#
# * Mythology and living longer - https://en.wikipedia.org/wiki/Longevity_myths
#   * Myth (sotries past down)
#   * Twilight of Myth
#   * Antiquity (pre 2000 BCE, Manu, Krishna (125), Arjuna, Gilgamesh, Enkidu, Noah, Abraham (170ish))
#   * 100 Autumns - Rig-veda I, 89, 9
#   * History
# * Statistics: On Average we now live longer because of better Heath Informatics
# * Better Health Informatics, Better Life

# %% [markdown]
# ## Andrej Karpathy
#
# * https://karpathy.ai/

# %% [markdown]
# ## AI History
#
# https://www.youtube.com/watch?v=XfpMkf4rD6E
#
# * Machine Learning
#   * https://www.youtube.com/watch?v=vStJoetOxJg&list=PLkDaE6sCZn6FNC6YRfRQc_FbeQrF8BwGI
#   * https://www.coursera.org/specializations/machine-learning-introduction
#   * Things didn't always work with vision
# * Deep Learning
#   * https://www.youtube.com/watch?v=CS4cs9xVecg&list=PLkDaE6sCZn6Ec-XTbcX1uRg2_u4xOEky0
#   * https://www.coursera.org/specializations/machine-learning-introduction
#   * ImageNet Classification with Deep Convolutional Neural Networks 2012 was turning point
#   * Up till now concentration was on algorithims, but ImageNet showed that Neural Nets worked and scaled nicely
#   * Neural Nets pop up in vision, NLP, Speech, Translation, RL
# * AI - Attention Is All You Need 2017 - a very unassuming looking machine translation paper
#   * The transformer
#   * Much easier to copy paste this architecture every where - vision, nlp, rl, speech, translation, graphs/science

# %% [markdown]
# * 2003 A Neural Probabilistic Language Model by Bengio et al - Multilayer Perceptron
# * 2014 Sequence to Sequence Learning with Neural Networks by Sutskever et al, LSTM Encoder Decoder Bottlenecks
# * 2014 Neural Machine Translation By Jointly Learning to Align and Translate by Bahdanau et al - the use of a fixed-length vector is a bottleneck in improving the performance of this basic encoder-decoder architecture, and propose to extend this by allowing a model to automatically (soft-) search for parts of a source sentence that are relevant to predicting a target word, without having to form these parts as a hard segment explicitly, the first use of attention?

# %% [markdown]
# * Go to email in video 19:31 3rd paragraph learning a language by gazing back and forth
# * Bahdanau called this RNNSearch but later got renamed to Attention
# * Attention at 20:00

# %% [markdown]
# ## The Maths
#
# Cosine Similarity
#
# * $sim(x,y) = cos(\theta) = \frac{x * y}{||x||||y||} = \frac{\sum{AB}}{\sqrt{\sum{A^2 B^2}}}$
# * Normalizing - a factor that makes the norm or some associated quantity such as an integral equal to a desired value (usually 1)
#
# Dot Product
#
# * $\sum{ab} = a^Tb = ||a||||b||cos\theta$
# * numpy.dot a = A @ B or a = numpy.dot(A,B)
#
# Softmax
#
# * $\sigma(\vec{z})_i = \frac{e^{z_i}}{\sum^K_{j=1} e^{z_j}}$
#
# Context Vector, see Bahdanau
#
# * https://arxiv.org/pdf/1409.0473
#
# Resources
#
# * https://www.youtube.com/watch?v=fIzYsrR-5Bs
# * https://youtu.be/xxpc-HPKN28
# * https://youtu.be/HfACrKJ_Y2w
# * Khan Academy and Brilliant.org
# * https://youtu.be/JnTa9XtvmfI
# * https://towardsdatascience.com/what-15-data-scientists-say-about-key-skills-79155813be5a
# * https://towardsdatascience.com/how-to-learn-the-math-needed-for-data-science-86c6643b0c59

# %% [markdown]
# ## AI Tools
#
# Colab
# * https://blog.google/technology/developers/google-colab-ai-coding-features/
# * https://colab.research.google.com/
#
# Google AI Studio
# * https://ai.google.dev/gemini-api/docs/ai-studio-quickstart
# * https://aistudio.google.com/app/prompts/new_chat
#
# Notebook LM
# * https://www.tomsguide.com/ai/googles-new-ai-tool-is-a-game-changer-for-students-heres-how-it-works
# * https://notebooklm.google/

# %% [markdown]
# ## Application Programming Interface
#
# An API is a software interface that allows different software components to communicate with each other. APIs are used to connect applications to other applications, servers, and consumers.

# %% [markdown]
# ## OpenAI Billing
#
# * Use the free models to work through any problems before spending any money
# * 7 cents

# %% [markdown]
# ## Model Servers
#
# * https://lmstudio.ai/
# * https://ollama.com/
# * Compared to https://aistudio.google.com/app/prompts/new_chat

# %% [markdown]
# ## Huggingface

# %%
# https://huggingface.co/models
import requests
from google.colab import userdata
import textwrap

API_URL = "https://api-inference.huggingface.co/models/openai-community/gpt2"
headers = {"Authorization": f"Bearer {userdata.get('HF_TOKEN')}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

def wrap(x):
  return textwrap.fill(x, replace_whitespace=False, fix_sentence_endings=True)

prompt = f'''
What is the meaning of life?
'''

output = query({
	"inputs": prompt,
})

print(output)

print(wrap(output[0]['generated_text']))
# Out:
# [{'generated_text': '\nWhat is the meaning of life?\n\nHow are the premodern phases as received in the lives of Christ? Explain the factors leading to and creating eternal life and the realities of eternal creation. Include realistic forecasts to prepare the ideal life for mankind.\n\nBy being a initiator continue to receive instruction in how God transforms the nations of this world into integral individual States. How do oracles relate to these events in all that is possible for Mankind?\n\nRelax and pivot from mini world and floating cocoons to a living'}]
#
# What is the meaning of life?
#
# How are the premodern phases as
# received in the lives of Christ?  Explain the factors leading to and
# creating eternal life and the realities of eternal creation.  Include
# realistic forecasts to prepare the ideal life for mankind.
#
# By being a
# initiator continue to receive instruction in how God transforms the
# nations of this world into integral individual States.  How do oracles
# ...

# %%
prompt = input('How can I help you? ')

output = query({
	"inputs": prompt,
})

print(wrap(output[0]['generated_text']))
# Out:
# How can I help you? What is the meaning of life?
# What is the meaning of life?
#
# Christianity has given life to "life",
# its holy attribute.  Emergent science reveals that human morals are
# infallible and God's will.  "Life" is linked to two crucial parts of
# life–criticism, in many religions, and exercise of grace and
# authority–45.
#
# What is your conception of spirituality?
#
# Oh, simply
# freedom: truth is fully known by its applicability to the objective
# reality of our world.  Catholicism that believes in Divine providence
# calls attention

# %% [markdown]
# ## LangChain and Chroma
#
# * https://python.langchain.com/docs/integrations/vectorstores/chroma/
# * Huggingface Tokens: https://huggingface.co/docs/hub/en/security-tokens

# %% [markdown]
# ## Why LangChain
#
# * https://www.udemy.com/course/chatgpt-and-langchain-the-complete-developers-masterclass/
# * https://pdf.ai/
#
# Steps
#
# * Open pdf and parse text
# * Chunk text (overlap)
# * Embed chunks
# * Store results (vector store / database)
# * Analyze query
# * Similarity search
# * Format query and similarity results into prompt
# * Send to LLM
# * Manage response from LLM

# %% [markdown]
# LangChain Sections
#
# * Model IO - easily switch between models
# * Data Connection - data sources, documents, vector stores, AWS, GCP, etc
# * Chains - output from one operation becomes input to another, separate out work between models, allowing you to swap LLMs in the middle of a chain
# * Memory - allows models to retain historical context, conversations, previous interactions
# * Side note - continuous asynchronous chats with Gemini, or my Jinn
# * Agents - specialty functions using tools (models, data connections, chains, memory, etc) to reason through problems and solutions

# %%
pip install -qU "langchain-chroma>=0.1.2" langchain-huggingface
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.5/602.5 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 58.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
# ...

# %%
# define embeddings
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# ...

# %%
# create vector store
from langchain_chroma import Chroma

vector_store = Chroma(
    collection_name="example_collection",
    embedding_function=embeddings,
    persist_directory="./chroma_langchain_db",  # Where to save data locally, remove if not necessary
)

# %%
# store documents
from uuid import uuid4

from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
    id=1,
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
    id=2,
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
    id=3,
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
    id=4,
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
    id=5,
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
    id=6,
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
    id=7,
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
    id=8,
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
    id=9,
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
    id=10,
)

documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]
uuids = [str(uuid4()) for _ in range(len(documents))]

vector_store.add_documents(documents=documents, ids=uuids)
# Out:
# ['e331d224-760a-4399-983e-b81b296958aa',
#  '226ff41a-9e45-406d-8442-66cbc9ce6f47',
#  '485864e2-e6ab-4c43-8b03-b375dabaed1d',
#  '35aaddce-b9d1-40fd-bf7f-6581f042c37a',
#  '31173b85-5850-44ba-be59-ffe7ce92f132',
#  '187b5cdf-b2a9-47dd-84c2-f7dd13aa4285',
#  'fd175577-2c87-417e-a36d-a95c19b597bc',
#  '5f730e8b-6a9f-4943-8373-d80490a4a339',
#  'e3539a14-6919-4217-8c05-a68e602959a9',
#  '60b6d65d-e77c-4694-b84b-45e0ad2149d8']

# %%
# update documents
updated_document_1 = Document(
    page_content="I had chocolate chip pancakes and fried eggs for breakfast this morning.",
    metadata={"source": "tweet"},
    id=1,
)

updated_document_2 = Document(
    page_content="The weather forecast for tomorrow is sunny and warm, with a high of 82 degrees.",
    metadata={"source": "news"},
    id=2,
)

vector_store.update_document(document_id=uuids[0], document=updated_document_1)
# You can also update multiple documents at once
vector_store.update_documents(
    ids=uuids[:2], documents=[updated_document_1, updated_document_2]
)

# %%
# delete document
vector_store.delete(ids=uuids[-1])

# %%
# query vector store
results = vector_store.similarity_search(
    "LangChain provides abstractions to make working with LLMs easy",
    k=2,
    filter={"source": "tweet"},
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")
# Out:
# * Building an exciting new project with LangChain - come check it out! [{'source': 'tweet'}]
# * LangGraph is the best framework for building stateful, agentic applications! [{'source': 'tweet'}]

# %%
results = vector_store.similarity_search_with_score(
    "Will it be hot tomorrow?", k=1, filter={"source": "news"}
)
for res, score in results:
    print(f"* [SIM={score:3f}] {res.page_content} [{res.metadata}]")
# Out:
# * [SIM=0.753576] The weather forecast for tomorrow is sunny and warm, with a high of 82 degrees. [{'source': 'news'}]

# %%
results = vector_store.similarity_search_by_vector(
    embedding=embeddings.embed_query("I love green eggs and ham!"), k=1
)
for doc in results:
    print(f"* {doc.page_content} [{doc.metadata}]")
# Out:
# * I had chocolate chip pancakes and fried eggs for breakfast this morning. [{'source': 'tweet'}]

# %%
# https://api.python.langchain.com/en/latest/vectorstores/langchain_core.vectorstores.VectorStore.html
retriever = vector_store.as_retriever(
    search_type="mmr", search_kwargs={"k": 1, "fetch_k": 5}
)
retriever.invoke("Stealing from the bank is a crime", filter={"source": "news"})
# Out:
# [Document(metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.')]

# %% [markdown]
# # OOP

# %% [markdown]
# # Business Problem
