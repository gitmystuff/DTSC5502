# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC5502/blob/main/Module_13-Time_Series/Module_13_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 13 - Assignment
#
# Name

# %% [markdown]
# ## Getting Started
#
# * Colab - get notebook from gitmystuff DTSC5502 repository
# * Save a Copy in Drive
# * Remove Copy of
# * Submit shared link in Canvas

# %% [markdown]
# ## Instructions
#
# The following code generates 12 years of data very similar to the data and code discussed in class. Please run the two cells below, generating the data, and then, using the code examples provided in class, complete this notebook. Only code covered in class will be considered.

# %%
# # seed
# import random

# # replace the following with your student id
# student_id = 123456789
# random_state = random.seed(student_id)
# random_state

# %%
# import numpy as np
# import pandas as pd
# import random
# from datetime import datetime, timedelta

# start_year = random.randint(2000, 2050)
# start_date = datetime(start_year, 1, 1, 00, 00, 00)
# end_date = start_date + timedelta(days=365*12)
# date_rng = pd.date_range(start=start_date, end=end_date, freq='MS').strftime("%Y-%m-%d %H:%M:%S")

# # Generate a base series with an upward trend
# base_feature = np.linspace(1000, 5000, len(date_rng))  # Start with 1000, steadily increase to 5000

# # Add some random noise to simulate real-world fluctuations
# noise = np.random.normal(0, 200, len(date_rng))
# feature = base_feature + noise

# # Ensure no negative or zero values
# feature = np.maximum(feature, 1)
# feature = np.round(feature).astype(int)  # Round to integers and convert to int

# df = pd.DataFrame({'feature': feature, 'Date': date_rng})
# print(df.shape)
# print(df.info())
# print(df.head())
# print(df.tail())

# %%
# make the date the index and format it to Year, month, and day

# %%
# create columns the contain the numeric year, numeric month, numeric day, and the first 3 characters of the proper month name

# %%
# ets decomposition

# %%
# add 6 and 12 month sma and annual ewma to the df

# %%
# add Holt-Winters SES, DES, and TES smoothing

# %%
# plot df

# %%
# zoom in first two years

# %%
# tail

# %%
# zoom in last two years

# %%
# make predictions using Exponential Smoothing from tsa.holtwinters and plot the train and test feature data with the predictions

# %%
# provide MAE, MSE, and RMSE metrics for the feature

# %%
# make an ACF plot

# %%
# make a PACF plot (worth 1 pt)

# %%
# use auto_arima to summarize the best SARIMA(X) model to use

# %%
# create the model

# %%
# make predictions
