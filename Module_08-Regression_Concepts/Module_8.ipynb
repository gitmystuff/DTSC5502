# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC5502/blob/main/Module_08-Regression_Concepts/Module_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 8

# %% [markdown]
# ## Outline
#
# * Transformers
# * pytest - https://lubna2004.medium.com/introduction-to-testing-with-pytest-on-colab-4e66e39b05bc
# * Regression Concepts
# * Working with Addresses
# * Copy and Paste Cells
# * Data Structures and Algorithms - https://towardsdatascience.com/arrays-data-structures-algorithms-for-data-scientists-b2e39e25136d
# * Data Science Road Map - https://towardsdatascience.com/what-you-need-to-know-before-switching-to-a-data-science-career-in-2024-9d6d623f1438

# %% [markdown]
# ## Transformers
#
# See Notebook

# %% [markdown]
# ## pytest
#
# https://docs.pytest.org/en/stable/getting-started.html

# %%
# %%file test_add_example.py

def add(x, y):
  """This function adds two numbers."""
  return x + y

def test_add():
  """This test function checks the add function."""
  assert add(2, 3) == 5
# Out:
# Writing test_add_example.py

# %%
# %%file test_subtract_example.py

def subtract(x, y):
  """This function adds two numbers."""
  return x - y

def test_subtract():
  """This test function checks the subtract function."""
  assert subtract(2, 3) == 0
# Out:
# Overwriting test_subtract_example.py

# %%
# !pytest
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.10.12, pytest-7.4.4, pluggy-1.5.0
# rootdir: /content
# plugins: anyio-3.7.1, typeguard-4.3.0
# collected 2 items
#
# test_add_example.py .                                                                        [ 50%]
# test_subtract_example.py F                                                                   [100%]
#
# ============================================= FAILURES =============================================
# __________________________________________ test_subtract ___________________________________________
#
#     def test_subtract():
#       """This test function checks the subtract function."""
# >     assert subtract(2, 3) == 0
# E     assert -1 == 0
# E      +  where -1 = subtract(2, 3)
#
# test_subtract_example.py:8: AssertionError
# ===================================== short test summary info ======================================
# ...

# %% [markdown]
# ## Regression Concepts
#
# * Linear Regression - https://github.com/gitmystuff/DSChunks/blob/main/Linear%20Regression.ipynb
# * Bessel's Correction - https://github.com/gitmystuff/DSChunks/blob/main/Bessels%20Correction.ipynb
# * Plotly Residuals
# * Linear Regression Metrics and Coefficients - https://colab.research.google.com/github/gitmystuff/DSChunks/blob/main/Linear_Regression_Metrics_and_Coefficients.ipynb
# * Coefficient Interpretation - https://colab.research.google.com/github/gitmystuff/DSChunks/blob/main/Coefficient%20Interpretation.ipynb
# * Logistic Regression - https://colab.research.google.com/github/gitmystuff/DSChunks/blob/main/Logistic_Regression.ipynb

# %% [markdown]
# ## Parsing Addresses

# %%
import re

def parse_address(text):
  """
  Parses an address string into street address, city, state, and zipcode.

  Args:
    text: The address string to parse.

  Returns:
    A dictionary containing the parsed address components.
  """

  # Regular expression to match address components
  pattern = r'^(.*?)\n(.*?),\s*([A-Z]{2})\s*(\d{5})$'
  match = re.match(pattern, text)

  if match:
    street_address = match.group(1)
    city = match.group(2)
    state = match.group(3)
    zipcode = match.group(4)
    return {
        'street_address': street_address,
        'city': city,
        'state': state,
        'zipcode': zipcode
    }
  else:
    return None

# Example usage
text = "80974 Jeffrey Mountains\nWest Benjamin, IL 82801"
address = parse_address(text)

if address:
  print(address)
else:
  print("Could not parse the address.")
# Out:
# {'street_address': '80974 Jeffrey Mountains', 'city': 'West Benjamin', 'state': 'IL', 'zipcode': '82801'}

# %%
def parse_address_v2(text):
  """
  Parses an address string into street address, city, state, and zipcode.
  This version handles potential variations in the input format.

  Args:
    text: The address string to parse.

  Returns:
    A dictionary containing the parsed address components.
  """

  try:
    # Split the input into lines
    lines = text.strip().split('\n')

    # Extract the street address from the first line
    street_address = lines[0].strip()

    # Extract the city, state, and zipcode from the second line
    city_state_zip = lines[1].strip().split(',')
    city = city_state_zip[0].strip()
    state_zip = city_state_zip[1].strip().split()
    state = state_zip[0].strip()
    zipcode = state_zip[1].strip()

    return {
        'street_address': street_address,
        'city': city,
        'state': state,
        'zipcode': zipcode
    }

  except (IndexError, ValueError):
    return None

# Example usage
text = "80974 Jeffrey Mountains\nWest Benjamin, IL 82801"
address = parse_address_v2(text)

if address:
  print(address)
else:
  print("Could not parse the address.")
# Out:
# {'street_address': '80974 Jeffrey Mountains', 'city': 'West Benjamin', 'state': 'IL', 'zipcode': '82801'}

# %%
# Apply the parse_address function to each row of the 'address' column
df[['nu_address', 'nu_city', 'nu_state', 'nu_zipcode']] = df['address'].apply(lambda x: pd.Series(parse_address(x)))

print(df)

# %% [markdown]
# ## Make Me Data Science III
