# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC5502/blob/main/Module_09-Feature_Selection/Module_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 9

# %% [markdown]
# ## Outline
#
# * Transformer Breakdown Pt I - https://docs.google.com/document/d/178JhgrTmntWc0CEBTEjzHC63VFZChSxOse4BHB_tB0I/edit?usp=sharing
# * Wikinator I (GENAI Folder)
# * Feature Selection - The Titanic
#   * https://colab.research.google.com/github/gitmystuff/DSChunks/blob/main/Feature_Selection_Methods.ipynb
#   * Overfitting
#   * Regularization
#   * Cross Validation
#   * Bootstrapping - https://colab.research.google.com/github/gitmystuff/DSChunks/blob/main/Bootstrapping.ipynb
#   * Monte Carlo Simulation - https://pbpython.com/monte-carlo.html, https://colab.research.google.com/github/gitmystuff/DSChunks/blob/main/Monte_Carlo_Simulation.ipynb
